# %%
# !pip install bokeh
# Out:
# Requirement already satisfied: bokeh in c:\users\matth\anaconda3\lib\site-packages (3.2.1)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\matth\anaconda3\lib\site-packages (from bokeh) (3.1.2)
# Requirement already satisfied: contourpy>=1 in c:\users\matth\anaconda3\lib\site-packages (from bokeh) (1.0.5)
# Requirement already satisfied: numpy>=1.16 in c:\users\matth\anaconda3\lib\site-packages (from bokeh) (1.24.3)
# Requirement already satisfied: packaging>=16.8 in c:\users\matth\anaconda3\lib\site-packages (from bokeh) (23.0)
# Requirement already satisfied: pandas>=1.2 in c:\users\matth\anaconda3\lib\site-packages (from bokeh) (1.5.3)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\matth\anaconda3\lib\site-packages (from bokeh) (9.4.0)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\matth\anaconda3\lib\site-packages (from bokeh) (6.0)
# Requirement already satisfied: tornado>=5.1 in c:\users\matth\anaconda3\lib\site-packages (from bokeh) (6.3.2)
# Requirement already satisfied: xyzservices>=2021.09.1 in c:\users\matth\anaconda3\lib\site-packages (from bokeh) (2022.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\matth\anaconda3\lib\site-packages (from Jinja2>=2.9->bokeh) (2.1.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\matth\anaconda3\lib\site-packages (from pandas>=1.2->bokeh) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\matth\anaconda3\lib\site-packages (from pandas>=1.2->bokeh) (2022.7)
# Requirement already satisfied: six>=1.5 in c:\users\matth\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas>=1.2->bokeh) (1.16.0)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
from scipy.stats import linregress
from bokeh.plotting import figure, output_notebook, show

# %%
MLBpath = "Clean_Data/MLB_Wins_01_18_Clean.csv"
BBallpath = "Clean_Data/Basketball_Wins_01_18_Clean.csv"
Hockeypath = "Clean_Data/Hockey_Wins_Clean.csv"
MLSpath = "Clean_Data/MLS_Wins_01_18_Clean.csv"
Footballpath = "Clean_Data/Football_Wins_01_18_Clean.csv"
MainPath = "Sports_Teams_File.csv"
TitlesPath = "Clean_Data/cleanTitles.csv"
EconFile = "US_Can_Econ_Data.csv"
MLBdf = pd.read_csv(MLBpath)
BBalldf = pd.read_csv(BBallpath)
Hockeydf = pd.read_csv(Hockeypath)
MLSdf = pd.read_csv(MLSpath)
Footballdf = pd.read_csv(Footballpath)
Maindf = pd.read_csv(MainPath)
Titlesdf = pd.read_csv(TitlesPath)

# %%
MLBdf.head()
# Out:
#    Season  Wins  Loss                  Team  Matches  Percentage
# 0    2001    75    87    Los Angeles Angels      162       0.463
# 1    2001    92    70  Arizona Diamondbacks      162       0.568
# 2    2001    88    74        Atlanta Braves      162       0.543
# 3    2001    63    98     Baltimore Orioles      161       0.391
# 4    2001    82    79        Boston Red Sox      161       0.509

# %%
MLSdf.head()
# Out:
#    Season             Team  Matches  Wins  Ties  Loss LgRank  Percentage
# 0    2017      Atlanta Utd       34    15    10     9    4th       0.588
# 1    2018      Atlanta Utd       34    21     6     7    2nd       0.706
# 2    2001  Chicago Fire FC       27    16     5     6    2nd       0.685
# 3    2002  Chicago Fire FC       28    11     4    13    7th       0.464
# 4    2003  Chicago Fire FC       30    15     8     7    1st       0.633

# %%
BBalldf.head()
# Out:
#    Season                 Team  Matches  Wins  Loss  Percentage
# 0    2001        Atlanta Hawks       82    33    49       0.402
# 1    2001       Boston Celtics       82    49    33       0.598
# 2    2001    Charlotte Hornets       82    44    38       0.537
# 3    2001        Chicago Bulls       82    21    61       0.256
# 4    2001  Cleveland Cavaliers       82    29    53       0.354

# %%
Hockeydf.head()
# Out:
#    Season           Team  Matches  Wins  Loss  Ties  Over_Time_Loss  \
# 0    2006  Anaheim Ducks       82    48    20   NaN              14
# 1    2007  Anaheim Ducks       82    47    27   NaN               8
# 2    2008  Anaheim Ducks       82    42    33   NaN               7
# 3    2009  Anaheim Ducks       82    39    32   NaN              11
# 4    2010  Anaheim Ducks       82    47    30   NaN               5
#
#    Percentage
# 0       0.585
# 1       0.573
# 2       0.512
# 3       0.476
# 4       0.573

# %%
Footballdf.head()
# Out:
#    Season               Team  Wins  Loss  Ties  Percentage
# 0    2001  Arizona Cardinals     7     9     0       0.438
# 1    2002  Arizona Cardinals     5    11     0       0.313
# 2    2003  Arizona Cardinals     4    12     0       0.250
# 3    2004  Arizona Cardinals     6    10     0       0.375
# 4    2005  Arizona Cardinals     5    11     0       0.313

# %%
Titlesdf.head()
# Out:
#    year sport                winner          winner_metro winner_state  \
# 0  2001   NFL      Baltimore Ravens             Baltimore           MD
# 1  2001   NBA    Los Angeles Lakers           Los Angeles           CA
# 2  2001   NHL    Colorado Avalanche                Denver           CO
# 3  2001   MLS  San Jose Earthquakes  San Jose-Santa Clara           CA
# 4  2001   MLB  Arizona Diamondbacks               Phoenix           AZ
#
#             runner_up runner_up_metro runner_up_state       final_four3  \
# 0     New York Giants        New York              NY   Oakland Raiders
# 1  Philadelphia 76ers    Philadelphia              PA   Milwaukee Bucks
# 2   New Jersey Devils        New York              NY   St. Louis Blues
# 3           LA Galaxy     Los Angeles              CA      Chicago Fire
# 4    New York Yankees        New York              NY  Seattle Mariners
#
#   final_four3_metro final_four3_state          final_four4 final_four4_metro  \
# 0     San Francisco                CA    Minnesota Vikings       Twin Cities
# 1         Milwaukee                WI    San Antonio Spurs       San Antonio
# 2         St. Louis                MO  Pittsburgh Penguins        Pittsburgh
# 3           Chicago                IL         Miami Fusion             Miami
# 4           Seattle                WA       Atlanta Braves           Atlanta
#
#   final_four4_state
# 0                MN
# 1                TX
# 2                PA
# 3                FL
# 4                GA

# %%
Maindf.head()
# Out:
#   Sport       City          State                  Team Years Played
# 0   MLB    Phoenix        Arizona  Arizona Diamondbacks    2001-2018
# 1   MLB    Atlanta        Georgia        Atlanta Braves    2001-2018
# 2   MLB  Baltimore       Maryland     Baltimore Orioles    2001-2018
# 3   MLB     Boston  Massachusetts        Boston Red Sox    2001-2018
# 4   MLB    Chicago       Illinois     Chicago White Sox    2001-2018

# %%
MainNFL = Maindf[(Maindf["Sport"] == "NFL")]
MainNBA = Maindf[(Maindf["Sport"] == "NBA")]
MainMLB = Maindf[(Maindf["Sport"] == "MLB")]
MainMLS = Maindf[(Maindf["Sport"] == "MLS")]
MainNHL = Maindf[(Maindf["Sport"] == "NHL")]

FinalMainNFL = pd.merge(MainNFL, Footballdf, on = "Team", how = "left")
FinalMainNBA = pd.merge(MainNBA, BBalldf, on = "Team", how = "left")
FinalMainMLB = pd.merge(MainMLB, MLBdf, on = "Team", how = "left")
FinalMainMLS = pd.merge(MainMLS, MLSdf, on = "Team", how = "left")
FinalMainNHL = pd.merge(MainNHL, Hockeydf, on = "Team", how = "left")


FinalMainMLS = FinalMainMLS.drop(columns = ["Years Played"])
FinalMainMLB = FinalMainMLB.drop(columns = ["Years Played"])
FinalMainNBA = FinalMainNBA.drop(columns = ["Years Played"])
FinalMainNFL = FinalMainNFL.drop(columns = ["Years Played"])
FinalMainNHL = FinalMainNHL.drop(columns = ["Years Played"])

FinalMainNBA["Ties"] = 0
FinalMainMLB["Ties"] = 0

FinalMainMLS = FinalMainMLS.drop(columns = ["LgRank"])
FinalMainNHL = FinalMainNHL.drop(columns = ["Over_Time_Loss"])


FinalMainMLB["Ties"] = FinalMainMLB["Ties"].fillna(0)
FinalMainMLB["Wins"] = FinalMainMLB["Wins"].fillna(0)
FinalMainMLB["Loss"] = FinalMainMLB["Loss"].fillna(0)
FinalMainMLB["Season"] = FinalMainMLB["Season"].fillna(0)
FinalMainMLB["Percentage"] = FinalMainMLB["Percentage"].fillna(0)
FinalMainNHL["Ties"] = FinalMainNHL["Ties"].fillna(0)
FinalMainNHL["Wins"] = FinalMainNHL["Wins"].fillna(0)
FinalMainNHL["Loss"] = FinalMainNHL["Loss"].fillna(0)
FinalMainNHL["Season"] = FinalMainNHL["Season"].fillna(0)
FinalMainNHL["Percentage"] = FinalMainNHL["Percentage"].fillna(0)
FinalMainNBA["Ties"] = FinalMainNBA["Ties"].fillna(0)
FinalMainNBA["Wins"] = FinalMainNBA["Wins"].fillna(0)
FinalMainNBA["Loss"] = FinalMainNBA["Loss"].fillna(0)
FinalMainNBA["Season"] = FinalMainNBA["Season"].fillna(0)
FinalMainNBA["Percentage"] = FinalMainNBA["Percentage"].fillna(0)
FinalMainNFL["Ties"] = FinalMainNFL["Ties"].fillna(0)
FinalMainNFL["Wins"] = FinalMainNFL["Wins"].fillna(0)
FinalMainNFL["Loss"] = FinalMainNFL["Loss"].fillna(0)
FinalMainNFL["Season"] = FinalMainNFL["Season"].fillna(0)
FinalMainNFL["Percentage"] = FinalMainNFL["Percentage"].fillna(0)
FinalMainMLS["Ties"] = FinalMainMLS["Ties"].fillna(0)
FinalMainMLS["Wins"] = FinalMainMLS["Wins"].fillna(0)
FinalMainMLS["Loss"] = FinalMainMLS["Loss"].fillna(0)
FinalMainMLS["Season"] = FinalMainMLS["Season"].fillna(0)
FinalMainMLS["Percentage"] = FinalMainMLS["Percentage"].fillna(0)

FinalMainMLS.columns.values.tolist()

FinalMainMLS = FinalMainMLS[['Sport','City','State','Team','Season','Wins','Loss','Ties','Percentage']]
FinalMainMLB = FinalMainMLB[['Sport','City','State','Team','Season','Wins','Loss','Ties','Percentage']]
FinalMainNFL = FinalMainNFL[['Sport','City','State','Team','Season','Wins','Loss','Ties','Percentage']]
FinalMainNHL = FinalMainNHL[['Sport','City','State','Team','Season','Wins','Loss','Ties','Percentage']]
FinalMainNBA = FinalMainNBA[['Sport','City','State','Team','Season','Wins','Loss','Ties','Percentage']]


FinalMainMLB = FinalMainMLB.astype({'Wins': 'int64'})
FinalMainMLB = FinalMainMLB.astype({'Loss': 'int64'})
FinalMainMLB = FinalMainMLB.astype({'Season': 'int64'})

FinalMainNHL = FinalMainNHL.astype({'Wins': 'int64'})
FinalMainNHL = FinalMainNHL.astype({'Loss': 'int64'})
FinalMainNHL = FinalMainNHL.astype({'Ties': 'int64'})
FinalMainNHL = FinalMainNHL.astype({'Season': 'int64'})

FinalMainNBA = FinalMainNBA.astype({'Wins': 'int64'})
FinalMainNBA = FinalMainNBA.astype({'Loss': 'int64'})
FinalMainNBA = FinalMainNBA.astype({'Season': 'int64'})

df1 = [FinalMainNHL, FinalMainNFL, FinalMainMLB, FinalMainMLS, FinalMainNBA]
FinalMain = pd.concat(df1)

FinalMain
# Out:
#     Sport             City            State                Team  Season  Wins  \
# 0     NHL          Anaheim       California       Anaheim Ducks    2006    48
# 1     NHL          Anaheim       California       Anaheim Ducks    2007    47
# 2     NHL          Anaheim       California       Anaheim Ducks    2008    42
# 3     NHL          Anaheim       California       Anaheim Ducks    2009    39
# 4     NHL          Anaheim       California       Anaheim Ducks    2010    47
# ..    ...              ...              ...                 ...     ...   ...
# 534   NBA  Washington D.C.  Washington D.C.  Washington Wizards    2014    46
# 535   NBA  Washington D.C.  Washington D.C.  Washington Wizards    2015    41
# 536   NBA  Washington D.C.  Washington D.C.  Washington Wizards    2016    49
# 537   NBA  Washington D.C.  Washington D.C.  Washington Wizards    2017    43
# 538   NBA  Washington D.C.  Washington D.C.  Washington Wizards    2018    32
#
#      Loss  Ties  Percentage
# 0      20     0       0.585
# 1      27     0       0.573
# 2      33     0       0.512
# 3      32     0       0.476
# 4      30     0       0.573
# ..    ...   ...         ...
# 534    36     0       0.561
# 535    41     0       0.500
# 536    33     0       0.598
# 537    39     0       0.524
# 538    50     0       0.390
#
# [2416 rows x 9 columns]

# %%
Econdf = pd.read_csv(EconFile)
Econdf = Econdf.drop(columns = ["VAR"])

Econdf
EconLabordf = Econdf[(Econdf["Variable"] == "Employment at place of work")]
EconLaborProductdf = Econdf[(Econdf["Variable"] == "Labour productivity (GDP per worker in USD, constant prices, constant PPP, base year 2015)")]
EconGDPdf = Econdf[(Econdf["Variable"] == "GDP per capita (USD, constant prices, constant PPP, base year 2015)")]
EconGDPdf = EconGDPdf.rename(columns={"TIME":"Season", "Geography":"City"})
EconLabordf = EconLabordf.rename(columns={"TIME":"Season", "Geography":"City"})
EconLaborProductdf = EconLaborProductdf.rename(columns={"TIME":"Season", "Geography":"City"})
EconGDPdf

FinalGDP = FinalMain.merge(EconGDPdf, on = ["Season","City"])
FinalLabor = FinalMain.merge(EconLabordf, on = ["Season","City"])
FinalLaborProductdf = FinalMain.merge(EconLaborProductdf, on = ["Season","City"])

# %%
FinalGDP.head(20)
# Out:
#    Sport     City    State               Team  Season  Wins  Loss  Ties  \
# 0    NHL  Atlanta  Georgia  Atlanta Thrashers    2001    19    47    11
# 1    NFL  Atlanta  Georgia    Atlanta Falcons    2001     7     9     0
# 2    MLB  Atlanta  Georgia     Atlanta Braves    2001    88    74     0
# 3    NBA  Atlanta  Georgia      Atlanta Hawks    2001    33    49     0
# 4    NHL  Atlanta  Georgia  Atlanta Thrashers    2002    31    39     7
# 5    NFL  Atlanta  Georgia    Atlanta Falcons    2002     9     6     1
# 6    MLB  Atlanta  Georgia     Atlanta Braves    2002   101    59     0
# 7    NBA  Atlanta  Georgia      Atlanta Hawks    2002    35    47     0
# 8    NHL  Atlanta  Georgia  Atlanta Thrashers    2003    33    37     8
# 9    NFL  Atlanta  Georgia    Atlanta Falcons    2003     5    11     0
# 10   MLB  Atlanta  Georgia     Atlanta Braves    2003   101    61     0
# 11   NBA  Atlanta  Georgia      Atlanta Hawks    2003    28    54     0
# 12   NHL  Atlanta  Georgia  Atlanta Thrashers    2005    41    33     0
# 13   NFL  Atlanta  Georgia    Atlanta Falcons    2005     8     8     0
# 14   MLB  Atlanta  Georgia     Atlanta Braves    2005    90    72     0
# 15   NBA  Atlanta  Georgia      Atlanta Hawks    2005    26    56     0
# 16   NHL  Atlanta  Georgia  Atlanta Thrashers    2006    43    28     0
# 17   NFL  Atlanta  Georgia    Atlanta Falcons    2006     7     9     0
# 18   MLB  Atlanta  Georgia     Atlanta Braves    2006    79    83     0
# 19   NBA  Atlanta  Georgia      Atlanta Hawks    2006    30    52     0
#
#     Percentage        Country  \
# 0        0.299  United States
# 1        0.438  United States
# 2        0.543  United States
# 3        0.402  United States
# 4        0.421  United States
# 5        0.594  United States
# 6        0.631  United States
# 7        0.427  United States
# 8        0.451  United States
# 9        0.313  United States
# 10       0.623  United States
# 11       0.341  United States
# 12       0.500  United States
# 13       0.500  United States
# 14       0.556  United States
# 15       0.317  United States
# 16       0.524  United States
# 17       0.438  United States
# 18       0.488  United States
# 19       0.366  United States
#
#                                              Variable  Value
# 0   GDP per capita (USD, constant prices, constant...  64336
# 1   GDP per capita (USD, constant prices, constant...  64336
# 2   GDP per capita (USD, constant prices, constant...  64336
# 3   GDP per capita (USD, constant prices, constant...  64336
# 4   GDP per capita (USD, constant prices, constant...  63886
# 5   GDP per capita (USD, constant prices, constant...  63886
# 6   GDP per capita (USD, constant prices, constant...  63886
# 7   GDP per capita (USD, constant prices, constant...  63886
# 8   GDP per capita (USD, constant prices, constant...  64511
# 9   GDP per capita (USD, constant prices, constant...  64511
# 10  GDP per capita (USD, constant prices, constant...  64511
# 11  GDP per capita (USD, constant prices, constant...  64511
# 12  GDP per capita (USD, constant prices, constant...  66977
# 13  GDP per capita (USD, constant prices, constant...  66977
# 14  GDP per capita (USD, constant prices, constant...  66977
# 15  GDP per capita (USD, constant prices, constant...  66977
# 16  GDP per capita (USD, constant prices, constant...  65595
# 17  GDP per capita (USD, constant prices, constant...  65595
# 18  GDP per capita (USD, constant prices, constant...  65595
# 19  GDP per capita (USD, constant prices, constant...  65595

# %%
FinalLabor.head(20)
# Out:
#    Sport     City    State               Team  Season  Wins  Loss  Ties  \
# 0    NHL  Atlanta  Georgia  Atlanta Thrashers    2001    19    47    11
# 1    NFL  Atlanta  Georgia    Atlanta Falcons    2001     7     9     0
# 2    MLB  Atlanta  Georgia     Atlanta Braves    2001    88    74     0
# 3    NBA  Atlanta  Georgia      Atlanta Hawks    2001    33    49     0
# 4    NHL  Atlanta  Georgia  Atlanta Thrashers    2002    31    39     7
# 5    NFL  Atlanta  Georgia    Atlanta Falcons    2002     9     6     1
# 6    MLB  Atlanta  Georgia     Atlanta Braves    2002   101    59     0
# 7    NBA  Atlanta  Georgia      Atlanta Hawks    2002    35    47     0
# 8    NHL  Atlanta  Georgia  Atlanta Thrashers    2003    33    37     8
# 9    NFL  Atlanta  Georgia    Atlanta Falcons    2003     5    11     0
# 10   MLB  Atlanta  Georgia     Atlanta Braves    2003   101    61     0
# 11   NBA  Atlanta  Georgia      Atlanta Hawks    2003    28    54     0
# 12   NHL  Atlanta  Georgia  Atlanta Thrashers    2005    41    33     0
# 13   NFL  Atlanta  Georgia    Atlanta Falcons    2005     8     8     0
# 14   MLB  Atlanta  Georgia     Atlanta Braves    2005    90    72     0
# 15   NBA  Atlanta  Georgia      Atlanta Hawks    2005    26    56     0
# 16   NHL  Atlanta  Georgia  Atlanta Thrashers    2006    43    28     0
# 17   NFL  Atlanta  Georgia    Atlanta Falcons    2006     7     9     0
# 18   MLB  Atlanta  Georgia     Atlanta Braves    2006    79    83     0
# 19   NBA  Atlanta  Georgia      Atlanta Hawks    2006    30    52     0
#
#     Percentage        Country                     Variable    Value
# 0        0.299  United States  Employment at place of work  2686719
# 1        0.438  United States  Employment at place of work  2686719
# 2        0.543  United States  Employment at place of work  2686719
# 3        0.402  United States  Employment at place of work  2686719
# 4        0.421  United States  Employment at place of work  2670925
# 5        0.594  United States  Employment at place of work  2670925
# 6        0.631  United States  Employment at place of work  2670925
# 7        0.427  United States  Employment at place of work  2670925
# 8        0.451  United States  Employment at place of work  2687530
# 9        0.313  United States  Employment at place of work  2687530
# 10       0.623  United States  Employment at place of work  2687530
# 11       0.341  United States  Employment at place of work  2687530
# 12       0.500  United States  Employment at place of work  2876385
# 13       0.500  United States  Employment at place of work  2876385
# 14       0.556  United States  Employment at place of work  2876385
# 15       0.317  United States  Employment at place of work  2876385
# 16       0.524  United States  Employment at place of work  2989335
# 17       0.438  United States  Employment at place of work  2989335
# 18       0.488  United States  Employment at place of work  2989335
# 19       0.366  United States  Employment at place of work  2989335

# %%
FinalLaborProductdf.head(20)
# Out:
#    Sport     City    State               Team  Season  Wins  Loss  Ties  \
# 0    NHL  Atlanta  Georgia  Atlanta Thrashers    2001    19    47    11
# 1    NFL  Atlanta  Georgia    Atlanta Falcons    2001     7     9     0
# 2    MLB  Atlanta  Georgia     Atlanta Braves    2001    88    74     0
# 3    NBA  Atlanta  Georgia      Atlanta Hawks    2001    33    49     0
# 4    NHL  Atlanta  Georgia  Atlanta Thrashers    2002    31    39     7
# 5    NFL  Atlanta  Georgia    Atlanta Falcons    2002     9     6     1
# 6    MLB  Atlanta  Georgia     Atlanta Braves    2002   101    59     0
# 7    NBA  Atlanta  Georgia      Atlanta Hawks    2002    35    47     0
# 8    NHL  Atlanta  Georgia  Atlanta Thrashers    2003    33    37     8
# 9    NFL  Atlanta  Georgia    Atlanta Falcons    2003     5    11     0
# 10   MLB  Atlanta  Georgia     Atlanta Braves    2003   101    61     0
# 11   NBA  Atlanta  Georgia      Atlanta Hawks    2003    28    54     0
# 12   NHL  Atlanta  Georgia  Atlanta Thrashers    2005    41    33     0
# 13   NFL  Atlanta  Georgia    Atlanta Falcons    2005     8     8     0
# 14   MLB  Atlanta  Georgia     Atlanta Braves    2005    90    72     0
# 15   NBA  Atlanta  Georgia      Atlanta Hawks    2005    26    56     0
# 16   NHL  Atlanta  Georgia  Atlanta Thrashers    2006    43    28     0
# 17   NFL  Atlanta  Georgia    Atlanta Falcons    2006     7     9     0
# 18   MLB  Atlanta  Georgia     Atlanta Braves    2006    79    83     0
# 19   NBA  Atlanta  Georgia      Atlanta Hawks    2006    30    52     0
#
#     Percentage        Country  \
# 0        0.299  United States
# 1        0.438  United States
# 2        0.543  United States
# 3        0.402  United States
# 4        0.421  United States
# 5        0.594  United States
# 6        0.631  United States
# 7        0.427  United States
# 8        0.451  United States
# 9        0.313  United States
# 10       0.623  United States
# 11       0.341  United States
# 12       0.500  United States
# 13       0.500  United States
# 14       0.556  United States
# 15       0.317  United States
# 16       0.524  United States
# 17       0.438  United States
# 18       0.488  United States
# 19       0.366  United States
#
#                                              Variable   Value
# 0   Labour productivity (GDP per worker in USD, co...  120789
# 1   Labour productivity (GDP per worker in USD, co...  120789
# 2   Labour productivity (GDP per worker in USD, co...  120789
# 3   Labour productivity (GDP per worker in USD, co...  120789
# 4   Labour productivity (GDP per worker in USD, co...  122340
# 5   Labour productivity (GDP per worker in USD, co...  122340
# 6   Labour productivity (GDP per worker in USD, co...  122340
# 7   Labour productivity (GDP per worker in USD, co...  122340
# 8   Labour productivity (GDP per worker in USD, co...  124485
# 9   Labour productivity (GDP per worker in USD, co...  124485
# 10  Labour productivity (GDP per worker in USD, co...  124485
# 11  Labour productivity (GDP per worker in USD, co...  124485
# 12  Labour productivity (GDP per worker in USD, co...  129708
# 13  Labour productivity (GDP per worker in USD, co...  129708
# 14  Labour productivity (GDP per worker in USD, co...  129708
# 15  Labour productivity (GDP per worker in USD, co...  129708
# 16  Labour productivity (GDP per worker in USD, co...  126717
# 17  Labour productivity (GDP per worker in USD, co...  126717
# 18  Labour productivity (GDP per worker in USD, co...  126717
# 19  Labour productivity (GDP per worker in USD, co...  126717

# %%
output_notebook()
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="c668d0c4-1db5-4280-b861-a1641005230a">Loading BokehJS ...</span>
#     </div>

# %%
EconGDPdf
# Out:
#             Country       City  \
# 18    United States  Salt Lake
# 19    United States  Salt Lake
# 20    United States  Salt Lake
# 21    United States  Salt Lake
# 22    United States  Salt Lake
# ...             ...        ...
# 9659  United States       Polk
# 9660  United States       Polk
# 9661  United States       Polk
# 9662  United States       Polk
# 9663  United States       Polk
#
#                                                Variable  Season  Value
# 18    GDP per capita (USD, constant prices, constant...    2001  49623
# 19    GDP per capita (USD, constant prices, constant...    2002  50222
# 20    GDP per capita (USD, constant prices, constant...    2003  50310
# 21    GDP per capita (USD, constant prices, constant...    2004  52758
# 22    GDP per capita (USD, constant prices, constant...    2005  55278
# ...                                                 ...     ...    ...
# 9659  GDP per capita (USD, constant prices, constant...    2014  69684
# 9660  GDP per capita (USD, constant prices, constant...    2015  75229
# 9661  GDP per capita (USD, constant prices, constant...    2016  76383
# 9662  GDP per capita (USD, constant prices, constant...    2017  73231
# 9663  GDP per capita (USD, constant prices, constant...    2018  73390
#
# [3240 rows x 5 columns]

# %%
FinalGDP.sort_values(by='Percentage', ascending = False)

FinalGDP2001 = FinalGDP[(FinalGDP["Season"] == 2001)]
FinalGDP2002 = FinalGDP[(FinalGDP["Season"] == 2002)]
FinalGDP2003 = FinalGDP[(FinalGDP["Season"] == 2003)]
FinalGDP2004 = FinalGDP[(FinalGDP["Season"] == 2004)]
FinalGDP2005 = FinalGDP[(FinalGDP["Season"] == 2005)]
FinalGDP2006 = FinalGDP[(FinalGDP["Season"] == 2006)]
FinalGDP2007 = FinalGDP[(FinalGDP["Season"] == 2007)]
FinalGDP2008 = FinalGDP[(FinalGDP["Season"] == 2008)]
FinalGDP2009 = FinalGDP[(FinalGDP["Season"] == 2009)]
FinalGDP2010 = FinalGDP[(FinalGDP["Season"] == 2010)]
FinalGDP2011 = FinalGDP[(FinalGDP["Season"] == 2011)]
FinalGDP2012 = FinalGDP[(FinalGDP["Season"] == 2012)]
FinalGDP2013 = FinalGDP[(FinalGDP["Season"] == 2013)]
FinalGDP2014 = FinalGDP[(FinalGDP["Season"] == 2014)]
FinalGDP2015 = FinalGDP[(FinalGDP["Season"] == 2015)]
FinalGDP2016 = FinalGDP[(FinalGDP["Season"] == 2016)]
FinalGDP2017 = FinalGDP[(FinalGDP["Season"] == 2017)]
FinalGDP2018 = FinalGDP[(FinalGDP["Season"] == 2018)]

FinalGDP2001
# Out:
#      Sport         City          State                    Team  Season  Wins  \
# 0      NHL      Atlanta        Georgia       Atlanta Thrashers    2001    19
# 1      NFL      Atlanta        Georgia         Atlanta Falcons    2001     7
# 2      MLB      Atlanta        Georgia          Atlanta Braves    2001    88
# 3      NBA      Atlanta        Georgia           Atlanta Hawks    2001    33
# 36     NHL       Boston  Massachusetts           Boston Bruins    2001    43
# ...    ...          ...            ...                     ...     ...   ...
# 1158   MLS   Providence   Rhode Island  New England Revolution    2001     7
# 1192   NBA      Memphis      Tennessee       Memphis Grizzlies    2001    23
# 1210   NBA     Portland         Oregon  Portland Trail Blazers    2001    49
# 1220   NBA   Sacramento     California        Sacramento Kings    2001    61
# 1238   NBA  San Antonio          Texas       San Antonio Spurs    2001    58
#
#       Loss  Ties  Percentage        Country  \
# 0       47    11       0.299  United States
# 1        9     0       0.438  United States
# 2       74     0       0.543  United States
# 3       49     0       0.402  United States
# 36      24     6       0.561  United States
# ...    ...   ...         ...            ...
# 1158    14     6       0.370  United States
# 1192    59     0       0.280  United States
# 1210    33     0       0.598  United States
# 1220    21     0       0.744  United States
# 1238    24     0       0.707  United States
#
#                                                Variable  Value
# 0     GDP per capita (USD, constant prices, constant...  64336
# 1     GDP per capita (USD, constant prices, constant...  64336
# 2     GDP per capita (USD, constant prices, constant...  64336
# 3     GDP per capita (USD, constant prices, constant...  64336
# 36    GDP per capita (USD, constant prices, constant...  71659
# ...                                                 ...    ...
# 1158  GDP per capita (USD, constant prices, constant...  43505
# 1192  GDP per capita (USD, constant prices, constant...  51428
# 1210  GDP per capita (USD, constant prices, constant...  53056
# 1220  GDP per capita (USD, constant prices, constant...  49056
# 1238  GDP per capita (USD, constant prices, constant...  39840
#
# [67 rows x 12 columns]

# %%
ByCity = FinalGDP.groupby("City")['Percentage'].mean()
ByCity.sort_values()
##ByCity.sort_values(by="Percentage")
# Out:
# City
# Jacksonville    0.396111
# Edmonton        0.428941
# Sacramento      0.439889
# Charlotte       0.457971
# Milwaukee       0.469083
# Minneapolis     0.471870
# Memphis         0.474833
# Cincinnati      0.478222
# Toronto         0.481692
# Phoenix         0.484458
# Providence      0.487333
# Columbus        0.488286
# San Diego       0.495441
# Calgary         0.497471
# Nashville       0.499457
# Chicago         0.499991
# St. Louis       0.500960
# Atlanta         0.501862
# Ottawa          0.505765
# Winnipeg        0.506000
# Houston         0.508924
# Montreal        0.509412
# Vancouver       0.511200
# New Orleans     0.511743
# Denver          0.513465
# Portland        0.523154
# Seattle         0.532000
# Dallas          0.546282
# Pittsburgh      0.549302
# Boston          0.552849
# Las Vegas       0.573000
# Indianapolis    0.580389
# San Antonio     0.702000
# Name: Percentage, dtype: float64

# %%
top = ["San Antonio", "Indianapolis", "Dallas", "Boston", "Pittsburgh"]
bottom = ["Jacksonville", "Minneapolis", "Sacramento", "Charlotte", "Milwaukee"]
topdict = {}
botdict = {}
i = 1

for row in FinalGDP.iterrows():
    if i < len(FinalGDP):
        if row[i][1] in top:
            if row[i][1] not in topdict:
                topdict[row[i][1]] = {row[i][4]: row[i][11]}
            elif row[i][1] in topdict:
               topdict[row[i][1]].update({row[i][4]: row[i][11]})
        if row[i][1] in bottom:
            if row[i][1] not in botdict:
                botdict[row[i][1]] = {row[i][4]: row[i][11]}
            elif row[i][1] in botdict:
               botdict[row[i][1]].update({row[i][4]: row[i][11]})
i = i + 1

# %%
topdict
# Out:
# {'Boston': {2001: 71659,
#   2002: 71282,
#   2003: 72170,
#   2005: 75953,
#   2006: 77623,
#   2007: 79787,
#   2008: 79792,
#   2009: 78644,
#   2010: 81405,
#   2011: 81718,
#   2012: 82903,
#   2013: 82610,
#   2014: 83295,
#   2015: 87060,
#   2016: 88688,
#   2017: 89833,
#   2018: 93218,
#   2004: 74310},
#  'Dallas': {2001: 54972,
#   2002: 55184,
#   2003: 54901,
#   2005: 58417,
#   2006: 60994,
#   2007: 61494,
#   2008: 61182,
#   2009: 56679,
#   2010: 57205,
#   2011: 58203,
#   2012: 58906,
#   2013: 59825,
#   2014: 60715,
#   2015: 61603,
#   2016: 62153,
#   2017: 62924,
#   2018: 64322,
#   2004: 56770},
#  'Pittsburgh': {2001: 53467,
#   2002: 54596,
#   2003: 56344,
#   2005: 58871,
#   2006: 58699,
#   2007: 60636,
#   2008: 61592,
#   2009: 61536,
#   2010: 64061,
#   2011: 64997,
#   2012: 66284,
#   2013: 67122,
#   2014: 68294,
#   2015: 70994,
#   2016: 70814,
#   2017: 73387,
#   2018: 76315,
#   2004: 58079},
#  'Indianapolis': {2001: 57381,
#   2002: 57306,
#   2003: 58420,
#   2004: 60513,
#   2005: 60187,
#   2006: 60815,
#   2007: 62016,
#   2008: 62854,
#   2009: 62348,
#   2010: 63252,
#   2011: 62939,
#   2012: 62502,
#   2013: 63620,
#   2014: 64451,
#   2015: 63350,
#   2016: 64421,
#   2017: 64200,
#   2018: 65836},
#  'San Antonio': {2001: 39840,
#   2002: 40288,
#   2003: 41204,
#   2004: 41716,
#   2005: 42492,
#   2006: 43660,
#   2007: 43665,
#   2008: 42920,
#   2009: 41522,
#   2010: 42161,
#   2011: 43042,
#   2012: 43501,
#   2013: 44782,
#   2014: 46191,
#   2015: 47262,
#   2016: 47057,
#   2017: 46420,
#   2018: 47851}}

# %%
top_df = pd.DataFrame(topdict).T
top_df.columns.tolist()
top_df = top_df[[2001,
 2002,
 2003,
 2004,
 2005,
 2006,
 2007,
 2008,
 2009,
 2010,
 2011,
 2012,
 2013,
 2014,
 2015,
 2016,
 2017,
 2018,]]
top_df
# Out:
#                2001   2002   2003   2004   2005   2006   2007   2008   2009  \
# Boston        71659  71282  72170  74310  75953  77623  79787  79792  78644
# Dallas        54972  55184  54901  56770  58417  60994  61494  61182  56679
# Pittsburgh    53467  54596  56344  58079  58871  58699  60636  61592  61536
# Indianapolis  57381  57306  58420  60513  60187  60815  62016  62854  62348
# San Antonio   39840  40288  41204  41716  42492  43660  43665  42920  41522
#
#                2010   2011   2012   2013   2014   2015   2016   2017   2018
# Boston        81405  81718  82903  82610  83295  87060  88688  89833  93218
# Dallas        57205  58203  58906  59825  60715  61603  62153  62924  64322
# Pittsburgh    64061  64997  66284  67122  68294  70994  70814  73387  76315
# Indianapolis  63252  62939  62502  63620  64451  63350  64421  64200  65836
# San Antonio   42161  43042  43501  44782  46191  47262  47057  46420  47851

# %%
botdict
# Out:
# {'Charlotte': {2001: 62341,
#   2002: 62602,
#   2003: 64034,
#   2004: 66293,
#   2005: 69138,
#   2006: 71442,
#   2007: 69697,
#   2008: 72023,
#   2009: 64362,
#   2010: 60963,
#   2011: 62859,
#   2012: 65967,
#   2013: 64369,
#   2014: 65415,
#   2015: 67627,
#   2016: 68670,
#   2017: 71024,
#   2018: 70944},
#  'Jacksonville': {2001: 46415,
#   2002: 47263,
#   2003: 48722,
#   2004: 49848,
#   2005: 50953,
#   2006: 51559,
#   2007: 51693,
#   2008: 49119,
#   2009: 46887,
#   2010: 46125,
#   2011: 45026,
#   2012: 45076,
#   2013: 45923,
#   2014: 46368,
#   2015: 47909,
#   2016: 48919,
#   2017: 49715,
#   2018: 50406},
#  'Minneapolis': {2001: 60413,
#   2002: 60670,
#   2003: 62867,
#   2004: 65028,
#   2005: 66811,
#   2006: 65632,
#   2007: 65868,
#   2008: 64563,
#   2009: 62291,
#   2010: 63433,
#   2011: 64313,
#   2012: 64967,
#   2013: 66057,
#   2014: 67832,
#   2015: 69224,
#   2016: 69702,
#   2017: 69963,
#   2018: 71641},
#  'Milwaukee': {2001: 55212,
#   2002: 54781,
#   2003: 55661,
#   2004: 56443,
#   2005: 58181,
#   2006: 59354,
#   2007: 59424,
#   2008: 57786,
#   2009: 56710,
#   2010: 57407,
#   2011: 58000,
#   2012: 58393,
#   2013: 58411,
#   2014: 58425,
#   2015: 59814,
#   2016: 60363,
#   2017: 60118,
#   2018: 61267},
#  'Sacramento': {2001: 49056,
#   2002: 49352,
#   2003: 50389,
#   2004: 51353,
#   2005: 52912,
#   2006: 53719,
#   2007: 53663,
#   2008: 52413,
#   2009: 50706,
#   2010: 49292,
#   2011: 49269,
#   2012: 49354,
#   2013: 50543,
#   2014: 51260,
#   2015: 53317,
#   2016: 53777,
#   2017: 54481,
#   2018: 56027}}

# %%
bot_df = pd.DataFrame(botdict).T
bot_df
# Out:
#                2001   2002   2003   2004   2005   2006   2007   2008   2009  \
# Charlotte     62341  62602  64034  66293  69138  71442  69697  72023  64362
# Jacksonville  46415  47263  48722  49848  50953  51559  51693  49119  46887
# Minneapolis   60413  60670  62867  65028  66811  65632  65868  64563  62291
# Milwaukee     55212  54781  55661  56443  58181  59354  59424  57786  56710
# Sacramento    49056  49352  50389  51353  52912  53719  53663  52413  50706
#
#                2010   2011   2012   2013   2014   2015   2016   2017   2018
# Charlotte     60963  62859  65967  64369  65415  67627  68670  71024  70944
# Jacksonville  46125  45026  45076  45923  46368  47909  48919  49715  50406
# Minneapolis   63433  64313  64967  66057  67832  69224  69702  69963  71641
# Milwaukee     57407  58000  58393  58411  58425  59814  60363  60118  61267
# Sacramento    49292  49269  49354  50543  51260  53317  53777  54481  56027

# %%
FinalGDP.sort_values(by="Value", ascending = False).head(40)
# Out:
#      Sport     City          State                 Team  Season  Wins  Loss  \
# 1097   MLS  Seattle     Washington  Seattle Sounders FC    2018    18    11
# 1096   MLB  Seattle     Washington     Seattle Mariners    2018    89    73
# 1095   NFL  Seattle     Washington     Seattle Seahawks    2018    10     6
# 86     NBA   Boston  Massachusetts       Boston Celtics    2018    49    33
# 85     MLB   Boston  Massachusetts       Boston Red Sox    2018   108    54
# 84     NHL   Boston  Massachusetts        Boston Bruins    2018    49    24
# 1093   MLB  Seattle     Washington     Seattle Mariners    2017    78    84
# 1092   NFL  Seattle     Washington     Seattle Seahawks    2017     9     7
# 1094   MLS  Seattle     Washington  Seattle Sounders FC    2017    14     9
# 83     NBA   Boston  Massachusetts       Boston Celtics    2017    55    27
# 81     NHL   Boston  Massachusetts        Boston Bruins    2017    50    20
# 82     MLB   Boston  Massachusetts       Boston Red Sox    2017    93    69
# 79     MLB   Boston  Massachusetts       Boston Red Sox    2016    93    69
# 80     NBA   Boston  Massachusetts       Boston Celtics    2016    53    29
# 78     NHL   Boston  Massachusetts        Boston Bruins    2016    44    31
# 1089   NFL  Seattle     Washington     Seattle Seahawks    2016    10     5
# 1090   MLB  Seattle     Washington     Seattle Mariners    2016    86    76
# 1091   MLS  Seattle     Washington  Seattle Sounders FC    2016    14    14
# 77     NBA   Boston  Massachusetts       Boston Celtics    2015    48    34
# 75     NHL   Boston  Massachusetts        Boston Bruins    2015    42    31
# 76     MLB   Boston  Massachusetts       Boston Red Sox    2015    78    84
# 1088   MLS  Seattle     Washington  Seattle Sounders FC    2015    15    13
# 1086   NFL  Seattle     Washington     Seattle Seahawks    2015    10     6
# 1087   MLB  Seattle     Washington     Seattle Mariners    2015    76    86
# 72     NHL   Boston  Massachusetts        Boston Bruins    2014    41    27
# 73     MLB   Boston  Massachusetts       Boston Red Sox    2014    71    91
# 74     NBA   Boston  Massachusetts       Boston Celtics    2014    40    42
# 1085   MLS  Seattle     Washington  Seattle Sounders FC    2014    20    10
# 1084   MLB  Seattle     Washington     Seattle Mariners    2014    87    75
# 1083   NFL  Seattle     Washington     Seattle Seahawks    2014    12     4
# 67     MLB   Boston  Massachusetts       Boston Red Sox    2012    69    93
# 68     NBA   Boston  Massachusetts       Boston Celtics    2012    41    40
# 66     NHL   Boston  Massachusetts        Boston Bruins    2012    28    14
# 70     MLB   Boston  Massachusetts       Boston Red Sox    2013    97    65
# 69     NHL   Boston  Massachusetts        Boston Bruins    2013    54    19
# 71     NBA   Boston  Massachusetts       Boston Celtics    2013    25    57
# 64     MLB   Boston  Massachusetts       Boston Red Sox    2011    90    72
# 63     NHL   Boston  Massachusetts        Boston Bruins    2011    49    29
# 65     NBA   Boston  Massachusetts       Boston Celtics    2011    39    27
# 61     MLB   Boston  Massachusetts       Boston Red Sox    2010    89    73
#
#       Ties  Percentage        Country  \
# 1097     5       0.603  United States
# 1096     0       0.549  United States
# 1095     0       0.625  United States
# 86       0       0.598  United States
# 85       0       0.667  United States
# 84       0       0.598  United States
# 1093     0       0.481  United States
# 1092     0       0.563  United States
# 1094    11       0.574  United States
# 83       0       0.671  United States
# 81       0       0.610  United States
# 82       0       0.574  United States
# 79       0       0.574  United States
# 80       0       0.646  United States
# 78       0       0.537  United States
# 1089     1       0.656  United States
# 1090     0       0.531  United States
# 1091     6       0.500  United States
# 77       0       0.585  United States
# 75       0       0.512  United States
# 76       0       0.481  United States
# 1088     6       0.529  United States
# 1086     0       0.625  United States
# 1087     0       0.469  United States
# 72       0       0.500  United States
# 73       0       0.438  United States
# 74       0       0.488  United States
# 1085     4       0.647  United States
# 1084     0       0.537  United States
# 1083     0       0.750  United States
# 67       0       0.426  United States
# 68       0       0.506  United States
# 66       0       0.583  United States
# 70       0       0.599  United States
# 69       0       0.659  United States
# 71       0       0.305  United States
# 64       0       0.556  United States
# 63       0       0.598  United States
# 65       0       0.591  United States
# 61       0       0.549  United States
#
#                                                Variable  Value
# 1097  GDP per capita (USD, constant prices, constant...  94868
# 1096  GDP per capita (USD, constant prices, constant...  94868
# 1095  GDP per capita (USD, constant prices, constant...  94868
# 86    GDP per capita (USD, constant prices, constant...  93218
# 85    GDP per capita (USD, constant prices, constant...  93218
# 84    GDP per capita (USD, constant prices, constant...  93218
# 1093  GDP per capita (USD, constant prices, constant...  90100
# 1092  GDP per capita (USD, constant prices, constant...  90100
# 1094  GDP per capita (USD, constant prices, constant...  90100
# 83    GDP per capita (USD, constant prices, constant...  89833
# 81    GDP per capita (USD, constant prices, constant...  89833
# 82    GDP per capita (USD, constant prices, constant...  89833
# 79    GDP per capita (USD, constant prices, constant...  88688
# 80    GDP per capita (USD, constant prices, constant...  88688
# 78    GDP per capita (USD, constant prices, constant...  88688
# 1089  GDP per capita (USD, constant prices, constant...  87158
# 1090  GDP per capita (USD, constant prices, constant...  87158
# 1091  GDP per capita (USD, constant prices, constant...  87158
# 77    GDP per capita (USD, constant prices, constant...  87060
# 75    GDP per capita (USD, constant prices, constant...  87060
# 76    GDP per capita (USD, constant prices, constant...  87060
# 1088  GDP per capita (USD, constant prices, constant...  85700
# 1086  GDP per capita (USD, constant prices, constant...  85700
# 1087  GDP per capita (USD, constant prices, constant...  85700
# 72    GDP per capita (USD, constant prices, constant...  83295
# 73    GDP per capita (USD, constant prices, constant...  83295
# 74    GDP per capita (USD, constant prices, constant...  83295
# 1085  GDP per capita (USD, constant prices, constant...  83046
# 1084  GDP per capita (USD, constant prices, constant...  83046
# 1083  GDP per capita (USD, constant prices, constant...  83046
# 67    GDP per capita (USD, constant prices, constant...  82903
# 68    GDP per capita (USD, constant prices, constant...  82903
# 66    GDP per capita (USD, constant prices, constant...  82903
# 70    GDP per capita (USD, constant prices, constant...  82610
# 69    GDP per capita (USD, constant prices, constant...  82610
# 71    GDP per capita (USD, constant prices, constant...  82610
# 64    GDP per capita (USD, constant prices, constant...  81718
# 63    GDP per capita (USD, constant prices, constant...  81718
# 65    GDP per capita (USD, constant prices, constant...  81718
# 61    GDP per capita (USD, constant prices, constant...  81405

# %%
from bokeh.palettes import Spectral4
from bokeh.plotting import figure, show
p = figure(width=800, height=250, x_axis_type="linear")
p.title.text = 'Click on legend entries to mute the corresponding lines'
p.line(FinalGDP['Season'], FinalGDP['Value'] , line_width=2, alpha=0.8, muted_alpha=0.2)
p.legend.location = "top_left"
p.legend.click_policy="mute"
show(p)
# Out:
# C:\Users\matth\AppData\Local\Temp\ipykernel_16476\3112849833.py:6: UserWarning:
# You are attempting to set `plot.legend.location` on a plot that has zero legends added, this will have no effect.
#
# Before legend properties can be set, you must add a Legend explicitly, or call a glyph method with a legend parameter set.
#
#   p.legend.location = "top_left"
# C:\Users\matth\AppData\Local\Temp\ipykernel_16476\3112849833.py:7: UserWarning:
# You are attempting to set `plot.legend.click_policy` on a plot that has zero legends added, this will have no effect.
#
# Before legend properties can be set, you must add a Legend explicitly, or call a glyph method with a legend parameter set.
#
#   p.legend.click_policy="mute"
#   <div id="c075acb0-bd60-4a88-b795-6f8f0650f5c7" data-root-id="p1085" style="display: contents;"></div>

# %%
p = figure(width = 400, height = 400)

# %%
p.vbar(x = df["Season"], top=df["Wins"], width=1)
# Out:
# GlyphRenderer(id='p1077', ...)

# %%
show(p)
# Out:
#   <div id="afd003b0-c77f-44ec-a9a3-91cba5343b62" data-root-id="p1043" style="display: contents;"></div>
