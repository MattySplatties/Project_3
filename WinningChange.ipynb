# %%
#import all the things..
#pandas for dataframes
import pandas as pd
#things not yet done?
import matplotlib.pyplot as plt
import scipy.stats as st
from scipy.stats import linregress
#new libary imports, to create plots and show them
from bokeh.plotting import figure, output_notebook, show 
# color palets
from bokeh.palettes import Spectral4
#So plots can be one above the other
from bokeh.layouts import column
#arrow annotation
from bokeh.models import Arrow, NormalHead, OpenHead, VeeHead
#lable annotation
from bokeh.models.annotations import Label
# title location (graph lables)
from bokeh.models import Title

# %%
#csv from db, now with year change values
new= pd.read_csv('../Clean_Data/EmploymentWinsDif.csv')
new.head()
# Out:
#    Unnamed: 0    City  Year      Win%  Win% Dif  Employment  Employment% Dif  \
# 0          18  Boston  2001  0.556000      0.00     2794673             0.00
# 1          19  Boston  2002  0.539000     -3.15     2741405            -1.94
# 2          20  Boston  2003  0.538667     -0.06     2708580            -1.21
# 3          21  Boston  2004  0.577000      6.64     2728596             0.73
# 4          22  Boston  2005  0.447333    -28.99     2763930             1.28
#
#    Win % Dif Value  Employment % Dif Value
# 0             0.00                    0.00
# 1            -3.15                   -1.94
# 2            -0.06                   -1.21
# 3             6.64                    0.73
# 4           -28.99                    1.28

# %%
Prod =pd.read_csv('ProductivityWinsDif.csv')
Prod.head()
# Out:
#    Unnamed: 0    City  Year      Win%  Win% Dif  Win% Dif Value  Productivity  \
# 0          18  Boston  2001  0.556000      0.00            0.00        138384
# 1          19  Boston  2002  0.539000     -3.15           -3.15        138822
# 2          20  Boston  2003  0.538667     -0.06           -0.06        142605
# 3          21  Boston  2004  0.577000      6.64            6.64        146543
# 4          22  Boston  2005  0.447333    -28.99          -28.99        149508
#
#    Productivity% Dif  Productivity% Dif Value
# 0               0.00                     0.00
# 1               0.32                     0.32
# 2               2.65                     2.65
# 3               2.69                     2.69
# 4               1.98                     1.98

# %%
#methord test
for city in  Prod.groupby(by= 'City'):
    print(city[1]['Productivity% Dif Value'])
    print(city[0])
# Out:
# 0     0.00
# 1     0.32
# 2     2.65
# 3     2.69
# 4     1.98
# 5     1.27
# 6     1.94
# 7     0.35
# 8     2.31
# 9     2.96
# 10    0.07
# 11    1.04
# 12    0.11
# 13   -0.72
# 14    3.36
# 15    0.68
# 16   -1.33
# 17    1.19
# Name: Productivity% Dif Value, dtype: float64
# Boston
# 18     0.00
# 19     2.90
# 20     2.80
# 21     5.09
# 22     4.95
# 23     2.54
# 24    -0.63
# 25     5.15
# 26    -3.97
# 27   -10.61
# 28     2.13
# 29     3.18
# 30    -3.09
# 31     0.15
# 32     1.95
# 33     0.30
# 34     3.40
# 35    -0.64
# Name: Productivity% Dif Value, dtype: float64
# Charlotte
# 36    0.00
# 37    3.28
# 38    1.08
# 39    3.11
# 40    2.22
# 41    4.99
# 42    1.75
# 43    0.86
# 44   -4.09
# 45   -0.17
# 46    1.16
# 47    0.68
# 48    1.14
# 49    0.54
# 50    1.10
# 51   -0.42
# 52    1.04
# 53    1.74
# Name: Productivity% Dif Value, dtype: float64
# Dallas
# 54    0.00
# 55    0.92
# 56    1.33
# 57    4.78
# 58   -0.55
# 59    0.32
# 60    3.25
# 61    1.66
# 62    4.81
# 63    4.72
# 64   -1.37
# 65   -0.84
# 66    0.78
# 67   -0.90
# 68   -4.05
# 69   -0.53
# 70   -0.74
# 71    1.86
# Name: Productivity% Dif Value, dtype: float64
# Indianapolis
# 72    0.00
# 73    5.38
# 74    4.33
# 75    2.16
# 76   -0.67
# 77   -0.10
# 78    0.13
# 79   -3.32
# 80    1.77
# 81   -1.75
# 82   -3.24
# 83   -0.52
# 84    0.65
# 85    0.59
# 86    3.01
# 87    1.51
# 88    1.05
# 89    0.90
# Name: Productivity% Dif Value, dtype: float64
# Jacksonville
# 90     0.00
# 91     1.84
# 92     2.27
# 93     1.50
# 94     3.21
# 95     0.61
# 96    -0.53
# 97    -2.57
# 98     3.42
# 99    -0.15
# 100    0.61
# 101    0.49
# 102   -0.49
# 103   -1.41
# 104    1.57
# 105   -0.32
# 106   -1.83
# 107    2.32
# Name: Productivity% Dif Value, dtype: float64
# Milwaukee
# 108    0.00
# 109    1.56
# 110    3.56
# 111    3.63
# 112    3.05
# 113   -1.16
# 114    1.50
# 115   -0.57
# 116    0.22
# 117    1.93
# 118    0.66
# 119    0.90
# 120    1.12
# 121    1.92
# 122    1.59
# 123    0.66
# 124   -1.06
# 125    2.11
# Name: Productivity% Dif Value, dtype: float64
# Minneapolis
# 126    0.00
# 127    2.59
# 128    3.83
# 129    2.27
# 130    0.91
# 131   -1.40
# 132    1.81
# 133    0.71
# 134    2.40
# 135    5.53
# 136    0.19
# 137    0.45
# 138    1.37
# 139    1.26
# 140    2.85
# 141   -0.52
# 142    2.23
# 143    3.01
# Name: Productivity% Dif Value, dtype: float64
# Pittsburgh
# 144    0.00
# 145    1.47
# 146    2.78
# 147    1.97
# 148    2.20
# 149    1.22
# 150    0.43
# 151    0.07
# 152    1.43
# 153    0.22
# 154    0.82
# 155   -1.00
# 156    1.68
# 157    0.85
# 158    2.72
# 159    0.03
# 160    1.28
# 161    1.62
# Name: Productivity% Dif Value, dtype: float64
# Sacramento
# 162    0.00
# 163    1.74
# 164    2.78
# 165    1.76
# 166    1.19
# 167    3.37
# 168    1.44
# 169   -1.14
# 170   -1.55
# 171   -0.61
# 172    2.08
# 173    0.55
# 174    2.46
# 175    2.35
# 176    1.86
# 177   -1.71
# 178   -1.25
# 179    2.92
# Name: Productivity% Dif Value, dtype: float64
# San Antonio

# %%
#methord test
for city in  new.groupby(by= 'City'):
   # print(city[1]['Employment% Dif'])
    print(city[0])
# Out:
# Boston
# Charlotte
# Dallas
# Indianapolis
# Jacksonville
# Milwaukee
# Minneapolis
# Pittsburgh
# Sacramento
# San Antonio

# %%
from bokeh.layouts import row
from bokeh.models import CrosshairTool, Span
from bokeh.plotting import figure, show
# rework with new df
years= [2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016,
 2017, 2018,]
# creates employment plot background
empl = figure(title= 'Yearly Employment Change', title_location='left', width=800, height=250, 
             x_axis_type="linear", tools='hover')

# colors for the viz
color_list = ['deepskyblue', 'mediumblue', 'darkcyan', 'lime', 'forestgreen', 'coral', 'red', 'orange','salmon', 'tomato']

#creates backgoround for win plot
win = figure(title= "Win Rate", title_location= 'left', width = 800, height = 400, tools= 'hover')

#create background for productivity
prod = figure(title= "Labor Productivity", title_location= 'left', width = 800, height = 400, tools= 'hover')

#creates words where title_location specifies
#Top.title.text = 'Click on legend entries to mute the corresponding lines'
prod.add_layout(Title(text="Click Citys for Color", align="center"), "below")

#counter for for loop
i =0

#for loop to create plots
for city in  new.groupby('City'):
# creates lines for employment
    empl.line(years, city[1]['Employment% Dif'] , line_width=2, alpha=0.2, muted_alpha=0.9, line_dash=[(i+1), 4],
             legend_label=city[0], line_color = color_list[i])
#creates bars for wins
    win.vbar(x= years, top= city[1]['Win % Dif Value'], width=0.8, fill_color= color_list[i],
              fill_alpha=0, muted_alpha=0.9, legend_label= city[0], line_width=1.2) 
#adds one to counter each time thru the loop
    i+=1
# 
# creates productivity lines
i=0
for city in  Prod.groupby(by= 'City'):
    prod.line(years, city[1]['Productivity% Dif Value'] , line_width=2, alpha=0.2, muted_alpha=0.9, line_dash=[(i+1), 4],
             legend_label=city[0], line_color = color_list[i])
    i+=1

#labels for charts
data_label = Label(
    x=2008,  # place the label at the same x coordinates as the recession
    y=4,  # place the label at y coordinates 
    x_offset=1,  # offset the label from the circle center by 12 pixels in the x direction
    text="2008", # the recession
    text_baseline="middle",  # align the text vertically to the middle of the circle
    text_color="olive",  # use a standard text property for the text color
)
#puts lable in Employment chart
empl.add_layout(data_label)
#puts lable in winnig rate chart
win.add_layout(data_label)
#label for productivity
prod.add_layout(data_label)

#creates arrow for both charts
arrow = Arrow(
    end=OpenHead(line_color="black", line_width=3),  # 🔁 try using  OpenHead or VeeHead instead of OpenHead
    line_width=3,
    line_color='black',
    x_start=2008,
    y_start=8,  # the start of the arrow, defined in data coordinates
    x_end=2008,
    y_end=-4,  # the tip of the arrow is at the minimum of the curve
)

#adds arrow to employment viz
empl.add_layout(arrow)
#adda arrow to winning
win.add_layout(arrow)
#add arrow to Productivity
prod.add_layout(arrow)


#puts top legend in place (employment)
empl.legend.location = "top_left"
# hides lines when legend is clicked (employment)
empl.legend.click_policy="mute"

#plot legend (winning)
win.legend.location='top_left'
#hides bars on click (note, this can also be done by changing "muted_alpha")
win.legend.click_policy='mute'

#plot legend (productivity)
prod.legend.location='top_left'
#hides bars on click (note, this can also be done by changing "muted_alpha")
prod.legend.click_policy='mute'


#crosshairs for plots, linked- setup
width = Span(dimension="width", line_dash="dashed", line_width=2)
height = Span(dimension="height", line_dash="dotted", line_width=2)
#add crosshairs
empl.add_tools(CrosshairTool(overlay=[width, height]))
win.add_tools(CrosshairTool(overlay=[width, height]))
prod.add_tools(CrosshairTool(overlay=[width, height]))

#displays plots, column puts them one on top of other
show(column(empl, win, prod))

# %% [markdown]
# # Refrences:
# color
# https://docs.bokeh.org/en/latest/docs/examples/basic/data/linear_cmap_colorbar.html
#
# multiplots
# https://docs.bokeh.org/en/2.4.1/docs/gallery/anscombe.html
# https://docs.bokeh.org/en/latest/docs/user_guide/interaction/linking.html#ug-interaction-linked <= Good refences for linking multiplots
#
# Bars
# https://docs.bokeh.org/en/latest/docs/examples/basic/bars/nested_colormapped.html
# https://docs.bokeh.org/en/latest/docs/user_guide/basic/bars.html
#
# Arrows
# https://docs.bokeh.org/en/latest/docs/examples/basic/annotations/arrow.html#index-0
# https://docs.bokeh.org/en/latest/docs/user_guide/basic/annotations.html <= everything about annotations (arrow and label refrence)
#
# Marker Shapes
# https://docs.bokeh.org/en/latest/docs/examples/basic/data/transform_markers.html
#
# Legends
# https://docs.bokeh.org/en/latest/docs/examples/models/legends.html
