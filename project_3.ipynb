# %%
# !pip install bokeh
# Out:
# Requirement already satisfied: bokeh in c:\users\matth\anaconda3\lib\site-packages (3.2.1)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\matth\anaconda3\lib\site-packages (from bokeh) (3.1.2)
# Requirement already satisfied: contourpy>=1 in c:\users\matth\anaconda3\lib\site-packages (from bokeh) (1.0.5)
# Requirement already satisfied: numpy>=1.16 in c:\users\matth\anaconda3\lib\site-packages (from bokeh) (1.24.3)
# Requirement already satisfied: packaging>=16.8 in c:\users\matth\anaconda3\lib\site-packages (from bokeh) (23.0)
# Requirement already satisfied: pandas>=1.2 in c:\users\matth\anaconda3\lib\site-packages (from bokeh) (1.5.3)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\matth\anaconda3\lib\site-packages (from bokeh) (9.4.0)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\matth\anaconda3\lib\site-packages (from bokeh) (6.0)
# Requirement already satisfied: tornado>=5.1 in c:\users\matth\anaconda3\lib\site-packages (from bokeh) (6.3.2)
# Requirement already satisfied: xyzservices>=2021.09.1 in c:\users\matth\anaconda3\lib\site-packages (from bokeh) (2022.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\matth\anaconda3\lib\site-packages (from Jinja2>=2.9->bokeh) (2.1.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\matth\anaconda3\lib\site-packages (from pandas>=1.2->bokeh) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\matth\anaconda3\lib\site-packages (from pandas>=1.2->bokeh) (2022.7)
# Requirement already satisfied: six>=1.5 in c:\users\matth\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas>=1.2->bokeh) (1.16.0)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
from scipy.stats import linregress
from bokeh.plotting import figure, output_notebook, show

# %%
MLBpath = "Clean_Data/MLB_Wins_01_18_Clean.csv"
BBallpath = "Clean_Data/Basketball_Wins_01_18_Clean.csv"
Hockeypath = "Clean_Data/Hockey_Wins_Clean.csv"
MLSpath = "Clean_Data/MLS_Wins_01_18_Clean.csv"
Footballpath = "Clean_Data/Football_Wins_01_18_Clean.csv"
MainPath = "Sports_Teams_File.csv"
TitlesPath = "Clean_Data/cleanTitles.csv"
MLBdf = pd.read_csv(MLBpath)
BBalldf = pd.read_csv(BBallpath)
Hockeydf = pd.read_csv(Hockeypath)
MLSdf = pd.read_csv(MLSpath)
Footballdf = pd.read_csv(Footballpath)
Maindf = pd.read_csv(MainPath)
Titlesdf = pd.read_csv(TitlesPath)

# %%
MLBdf.head()
# Out:
#    Season  Wins  Loss                  Team  Matches  Percentage
# 0    2001    75    87    Los Angeles Angels      162       0.463
# 1    2001    92    70  Arizona Diamondbacks      162       0.568
# 2    2001    88    74        Atlanta Braves      162       0.543
# 3    2001    63    98     Baltimore Orioles      161       0.391
# 4    2001    82    79        Boston Red Sox      161       0.509

# %%
MLSdf.head()
# Out:
#    Season           Team  Matches  Wins  Ties  Loss LgRank  Percentage
# 0    2001   Miami Fusion       26    16     5     5    1st       0.712
# 1    2001  Columbus Crew       26    13     6     7    4th       0.615
# 2    2001      LA Galaxy       26    14     5     7    3rd       0.635
# 3    2001   Chicago Fire       27    16     5     6    2nd       0.685
# 4    2002    Dallas Burn       28    12     7     9    3rd       0.554

# %%
BBalldf.head()
# Out:
#    Season                 Team  Matches  Wins  Loss  Percentage
# 0    2001        Atlanta Hawks       82    33    49       0.402
# 1    2001       Boston Celtics       82    49    33       0.598
# 2    2001    Charlotte Hornets       82    44    38       0.537
# 3    2001        Chicago Bulls       82    21    61       0.256
# 4    2001  Cleveland Cavaliers       82    29    53       0.354

# %%
Hockeydf.head()
# Out:
#    Season           Team  Matches  Wins  Loss  Ties  Over_Time_Loss  \
# 0    2006  Anaheim Ducks       82    48    20   NaN              14
# 1    2007  Anaheim Ducks       82    47    27   NaN               8
# 2    2008  Anaheim Ducks       82    42    33   NaN               7
# 3    2009  Anaheim Ducks       82    39    32   NaN              11
# 4    2010  Anaheim Ducks       82    47    30   NaN               5
#
#    Percentage
# 0       0.585
# 1       0.573
# 2       0.512
# 3       0.476
# 4       0.573

# %%
Footballdf.head()
# Out:
#    Season               Team  Wins  Loss  Ties  Percentage
# 0    2001  Arizona Cardinals     7     9     0       0.438
# 1    2002  Arizona Cardinals     5    11     0       0.313
# 2    2003  Arizona Cardinals     4    12     0       0.250
# 3    2004  Arizona Cardinals     6    10     0       0.375
# 4    2005  Arizona Cardinals     5    11     0       0.313

# %%
Titlesdf.head()
# Out:
#    year sport                winner          winner_metro winner_state  \
# 0  2001   NFL      Baltimore Ravens             Baltimore           MD
# 1  2001   NBA    Los Angeles Lakers           Los Angeles           CA
# 2  2001   NHL    Colorado Avalanche                Denver           CO
# 3  2001   MLS  San Jose Earthquakes  San Jose-Santa Clara           CA
# 4  2001   MLB  Arizona Diamondbacks               Phoenix           AZ
#
#             runner_up runner_up_metro runner_up_state       final_four3  \
# 0     New York Giants        New York              NY   Oakland Raiders
# 1  Philadelphia 76ers    Philadelphia              PA   Milwaukee Bucks
# 2   New Jersey Devils        New York              NY   St. Louis Blues
# 3  Los Angeles Galaxy     Los Angeles              CA      Chicago Fire
# 4    New York Yankees        New York              NY  Seattle Mariners
#
#   final_four3_metro final_four3_state          final_four4 final_four4_metro  \
# 0     San Francisco                CA    Minnesota Vikings       Twin Cities
# 1         Milwaukee                WI    San Antonio Spurs       San Antonio
# 2         St. Louis                MO  Pittsburgh Penguins        Pittsburgh
# 3           Chicago                IL         Miami Fusion             Miami
# 4           Seattle                WA       Atlanta Braves           Atlanta
#
#   final_four4_state
# 0                MN
# 1                TX
# 2                PA
# 3                FL
# 4                GA

# %%
Maindf.head()
# Out:
#   Sport       City           State               Team Years Played
# 0   NFL   Glendale         Arizona  Arizona Cardinals    2001-2018
# 1   NFL    Atlanta         Georgia    Atlanta Falcons    2001-2018
# 2   NFL  Baltimore        Maryland   Baltimore Ravens    2001-2018
# 3   NFL    Buffalo        New York      Buffalo Bills    2001-2018
# 4   NFL  Charlotte  North Carolina  Carolina Panthers    2001-2018

# %%
Temp1 = pd.merge(Maindf, MLBdf, on = "Team", how = "left")
#Temp1
Temp1[Temp1["Sport"].isin(["MLB"])]
# Out:
#     Sport       City     State               Team Years Played  Season  Wins  \
# 68    MLB  Baltimore  Maryland  Baltimore Orioles    2001-2018  2001.0  63.0
# 69    MLB  Baltimore  Maryland  Baltimore Orioles    2001-2018  2002.0  67.0
# 70    MLB  Baltimore  Maryland  Baltimore Orioles    2001-2018  2003.0  71.0
# 71    MLB  Baltimore  Maryland  Baltimore Orioles    2001-2018  2004.0  78.0
# 72    MLB  Baltimore  Maryland  Baltimore Orioles    2001-2018  2005.0  74.0
# ..    ...        ...       ...                ...          ...     ...   ...
# 550   MLB     Denver  Colorado   Colorado Rockies    2001-2018  2014.0  66.0
# 551   MLB     Denver  Colorado   Colorado Rockies    2001-2018  2015.0  68.0
# 552   MLB     Denver  Colorado   Colorado Rockies    2001-2018  2016.0  75.0
# 553   MLB     Denver  Colorado   Colorado Rockies    2001-2018  2017.0  87.0
# 554   MLB     Denver  Colorado   Colorado Rockies    2001-2018  2018.0  91.0
#
#      Loss  Matches  Percentage
# 68   98.0    161.0       0.391
# 69   95.0    162.0       0.414
# 70   91.0    162.0       0.438
# 71   84.0    162.0       0.481
# 72   88.0    162.0       0.457
# ..    ...      ...         ...
# 550  96.0    162.0       0.407
# 551  94.0    162.0       0.420
# 552  87.0    162.0       0.463
# 553  75.0    162.0       0.537
# 554  72.0    163.0       0.558
#
# [487 rows x 10 columns]

# %%
Temp2 = pd.merge(Temp1, BBalldf, on = "Team", how = "left")
Temp2[Temp2["Sport"].isin(["NBA"])]
# Out:
#     Sport             City            State                Team Years Played  \
# 34    NBA          Atlanta          Georgia       Atlanta Hawks    2001-2018
# 35    NBA          Atlanta          Georgia       Atlanta Hawks    2001-2018
# 36    NBA          Atlanta          Georgia       Atlanta Hawks    2001-2018
# 37    NBA          Atlanta          Georgia       Atlanta Hawks    2001-2018
# 38    NBA          Atlanta          Georgia       Atlanta Hawks    2001-2018
# ..    ...              ...              ...                 ...          ...
# 568   NBA  Washington D.C.  Washington D.C.  Washington Wizards    2001-2018
# 569   NBA  Washington D.C.  Washington D.C.  Washington Wizards    2001-2018
# 570   NBA  Washington D.C.  Washington D.C.  Washington Wizards    2001-2018
# 571   NBA  Washington D.C.  Washington D.C.  Washington Wizards    2001-2018
# 572   NBA  Washington D.C.  Washington D.C.  Washington Wizards    2001-2018
#
#      Season_x  Wins_x  Loss_x  Matches_x  Percentage_x  Season_y  Matches_y  \
# 34        NaN     NaN     NaN        NaN           NaN    2001.0       82.0
# 35        NaN     NaN     NaN        NaN           NaN    2002.0       82.0
# 36        NaN     NaN     NaN        NaN           NaN    2003.0       82.0
# 37        NaN     NaN     NaN        NaN           NaN    2004.0       82.0
# 38        NaN     NaN     NaN        NaN           NaN    2005.0       82.0
# ..        ...     ...     ...        ...           ...       ...        ...
# 568       NaN     NaN     NaN        NaN           NaN    2014.0       82.0
# 569       NaN     NaN     NaN        NaN           NaN    2015.0       82.0
# 570       NaN     NaN     NaN        NaN           NaN    2016.0       82.0
# 571       NaN     NaN     NaN        NaN           NaN    2017.0       82.0
# 572       NaN     NaN     NaN        NaN           NaN    2018.0       82.0
#
#      Wins_y  Loss_y  Percentage_y
# 34     33.0    49.0         0.402
# 35     35.0    47.0         0.427
# 36     28.0    54.0         0.341
# 37     13.0    69.0         0.159
# 38     26.0    56.0         0.317
# ..      ...     ...           ...
# 568    46.0    36.0         0.561
# 569    41.0    41.0         0.500
# 570    49.0    33.0         0.598
# 571    43.0    39.0         0.524
# 572    32.0    50.0         0.390
#
# [539 rows x 15 columns]

# %%
output_notebook()
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="d6b37281-dc8c-4350-949f-0dc44dd1e362">Loading BokehJS ...</span>
#     </div>

# %%
p = figure(width = 400, height = 400)

# %%
p.vbar(x = df["Season"], top=df["Wins"], width=1)
# Out:
# GlyphRenderer(id='p1077', ...)

# %%
show(p)
# Out:
#   <div id="afd003b0-c77f-44ec-a9a3-91cba5343b62" data-root-id="p1043" style="display: contents;"></div>
