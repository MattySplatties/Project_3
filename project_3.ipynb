# %%
# !pip install bokeh
# Out:
# Requirement already satisfied: bokeh in c:\users\matth\anaconda3\lib\site-packages (3.2.1)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\matth\anaconda3\lib\site-packages (from bokeh) (3.1.2)
# Requirement already satisfied: contourpy>=1 in c:\users\matth\anaconda3\lib\site-packages (from bokeh) (1.0.5)
# Requirement already satisfied: numpy>=1.16 in c:\users\matth\anaconda3\lib\site-packages (from bokeh) (1.24.3)
# Requirement already satisfied: packaging>=16.8 in c:\users\matth\anaconda3\lib\site-packages (from bokeh) (23.0)
# Requirement already satisfied: pandas>=1.2 in c:\users\matth\anaconda3\lib\site-packages (from bokeh) (1.5.3)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\matth\anaconda3\lib\site-packages (from bokeh) (9.4.0)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\matth\anaconda3\lib\site-packages (from bokeh) (6.0)
# Requirement already satisfied: tornado>=5.1 in c:\users\matth\anaconda3\lib\site-packages (from bokeh) (6.3.2)
# Requirement already satisfied: xyzservices>=2021.09.1 in c:\users\matth\anaconda3\lib\site-packages (from bokeh) (2022.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\matth\anaconda3\lib\site-packages (from Jinja2>=2.9->bokeh) (2.1.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\matth\anaconda3\lib\site-packages (from pandas>=1.2->bokeh) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\matth\anaconda3\lib\site-packages (from pandas>=1.2->bokeh) (2022.7)
# Requirement already satisfied: six>=1.5 in c:\users\matth\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas>=1.2->bokeh) (1.16.0)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
from scipy.stats import linregress
from bokeh.plotting import figure, output_notebook, show

# %%
path = "MLB_Wins_01_18_Clean.csv"

df = pd.read_csv(path)
df
# Out:
#      Season  Wins  Loss                  Team  Matches  percentage
# 0      2001    75    87    Los Angeles Angels      162       0.463
# 1      2001    92    70  Arizona Diamondbacks      162       0.568
# 2      2001    88    74        Atlanta Braves      162       0.543
# 3      2001    63    98     Baltimore Orioles      161       0.391
# 4      2001    82    79        Boston Red Sox      161       0.509
# ..      ...   ...   ...                   ...      ...         ...
# 535    2018    88    74   St. Louis Cardinals      162       0.543
# 536    2018    90    72        Tampa Bay Rays      162       0.556
# 537    2018    67    95         Texas Rangers      162       0.414
# 538    2018    73    89     Toronto Blue Jays      162       0.451
# 539    2018    82    80  Washington Nationals      162       0.506
#
# [540 rows x 6 columns]

# %%
output_notebook()
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="d6b37281-dc8c-4350-949f-0dc44dd1e362">Loading BokehJS ...</span>
#     </div>

# %%
p = figure(width = 400, height = 400)

# %%
p.vbar(x = df["Season"], top=df["Wins"], width=1)
# Out:
# GlyphRenderer(id='p1077', ...)

# %%
show(p)
# Out:
#   <div id="afd003b0-c77f-44ec-a9a3-91cba5343b62" data-root-id="p1043" style="display: contents;"></div>
